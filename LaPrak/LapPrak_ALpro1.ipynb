# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan python VScode dan sinkronisasi github”**
#
# **Disusun Oleh :**
#
# **Rahagi Yusrin**
#
# **2611537002**
#
# **Dosen Pengampu:**
#
# **Dr. ir. Wahyudi ST.MT.**
#
# **Asisten Praktikum:**
#
# **Nama Asisten**
#
# <br>
#
#  <img src="logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pekan 1 yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan Pengenalan Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep bahasa Python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 10 September, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pengenalan bahasa Python pada pertemuan pertama adalah hal yang wajib diberikan kepada mahasiswa baru, karena sangat berpengaruh pada rintangan rintangan yang berkaitan dengan program Python kedepannya, maka dari itu mahasiswa baru diharuskan untuk mengerti tentang konsep dan cara kerja python itu sendiri.
#
# ## 1.2 Tujuan
# 1. Mengenal konsep dasar Python.
# 2. Mengetahui latar belakang python.
#
# ## 1.3 Manfaat
# 1. Dapat mengembangkan bahasa Python yang telah dipelajari.
# 2. Dapat membuat program dasar dari bahasa Python.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Komentar dalam Python
#
#  Ditulis menggunakan tanda kutip tiga (""" ... """) atau tanda pagar (#).
#
#  Fungsinya:
#  a. Memberikan penjelasan tentang kode.
#  b. Tidak dieksekusi oleh interpreter.
#  c. Membantu dokumentasi program.
#
# 2. Fungsi print()
#
#  a. Digunakan untuk menampilkan output ke layar.
#  b. Bisa menampilkan teks, angka, atau hasil operasi.
#
# 3. String (Teks)
#
#  a. Ditulis di dalam tanda kutip " " atau ' '.
#  b. Bisa berupa kata, kalimat, atau simbol.
#  c. Contoh: "Departemen Informatika" adalah sebuah string.
#
# 4. Baris Kosong dengan print()
#
#  a. print() tanpa argumen menghasilkan baris kosong.
#  b. Digunakan untuk memberi jarak antar output agar lebih rapi.
#
# 5. Escape Character
#
#  Tanda \ digunakan untuk menampilkan karakter khusus.
#
#  Contoh:
#
#  \\ → menampilkan \
#  // → menampilkan //
#
# 6. Penggabungan String (Concatenation)
#
#  Operator [+] digunakan untuk menggabungkan beberapa string.
#   *Pada program ini, string digabung untuk menampilkan nama dan NIM.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Kelas C_2611537002"

# %%
print ("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" +" dibuat oleh "
      + "Rahagi Yusrin dan (NIM punya saya) 2611537002")
# Out:
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program ini dibuat oleh Rahagi Yusrin dan (NIM punya saya) 2611537002

# %% [markdown]
# **Penjelasan :**
# Kode ini berfungsi untuk menampilkan hasil [Print] yang kita gunakan untuk menyatakan sesuatu, disini saya juga menampilkan nama dan NIM saya.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Kelas C_2611537002"

# %%
# Kode jawaban tugas bagian a

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas ini ...

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa ...
#
# Dalam konteks pemrograman ..., konsep ini memanfaatkan ... sehingga ...

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Penulis, "Judul Referensi," Nama Situs/Jurnal, [Tahun]. [Online]. Tersedia: https://... [Diakses tanggal].
#
# [2] Penulis, "Judul Buku/Diktat," [Tahun], Hal. ...
